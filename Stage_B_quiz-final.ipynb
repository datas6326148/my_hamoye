# %% [markdown]
# # Non Normalized Version

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('energydata_complete.csv')

# %%
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
df.isnull().sum(axis = 0)
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
X = df['T2']
y = df['T6']

# %%
X=df['T2'].values.reshape(-1,1)
y=df['T6'].values.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=77, test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X_train,y_train)
y_predict= lin_reg.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, y_predict))
round(rmse,3)
# Out:
# 3.696

# %%
df = df.drop(columns=['date','lights'],axis=1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
normalized_df = pd.DataFrame(scaler.fit_transform(df),columns=df.columns)
normalized_df.head()
# Out:
#    Appliances       T1      RH_1        T2      RH_2        T3      RH_3  \
# 0    0.046729  0.32735  0.566187  0.225345  0.684038  0.215188  0.746066
# 1    0.046729  0.32735  0.541326  0.225345  0.682140  0.215188  0.748871
# 2    0.037383  0.32735  0.530502  0.225345  0.679445  0.215188  0.755569
# 3    0.037383  0.32735  0.524080  0.225345  0.678414  0.215188  0.758685
# 4    0.046729  0.32735  0.531419  0.225345  0.676727  0.215188  0.758685
#
#          T4      RH_4        T5  ...        T9      RH_9     T_out  \
# 0  0.351351  0.764262  0.175506  ...  0.223032  0.677290  0.372990
# 1  0.351351  0.782437  0.175506  ...  0.226500  0.678532  0.369239
# 2  0.344745  0.778062  0.175506  ...  0.219563  0.676049  0.365488
# 3  0.341441  0.770949  0.175506  ...  0.219563  0.671909  0.361736
# 4  0.341441  0.762697  0.178691  ...  0.219563  0.671909  0.357985
#
#    Press_mm_hg    RH_out  Windspeed  Visibility  Tdewpoint       rv1       rv2
# ...

# %%
feat_df = df.drop(columns=['Appliances'])
appliances = df['Appliances']

# %%
from sklearn.model_selection import train_test_split
lin_reg = LinearRegression()
X_train, X_test, y_train, y_test = train_test_split(feat_df, appliances, random_state=42, test_size=0.3)
lin_reg.fit(X_train,y_train)
y_predict= lin_reg.predict(X_test)

# %%
y_predict_train=lin_reg.predict(X_train)
from sklearn.metrics import mean_absolute_error
mae_train = mean_absolute_error(y_train, y_predict_train)
print('mae_train: ',round(mae_train,3))
# Out:
# mae_train:  53.749

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_predict)
print('mae_test: ',round(mae,3))
# Out:
# mae_test:  53.649

# %%
rmse_feat_train = np.sqrt(mean_squared_error(y_train, y_predict_train))
print('rmse_train: ',round(rmse_feat_train,3))
# Out:
# rmse_train:  95.216

# %%
from sklearn.metrics import mean_squared_error
rmse_feat = np.sqrt(mean_squared_error(y_test, y_predict))
print('rmse_test: ',round(rmse_feat,3))
# Out:
# rmse_test:  93.64

# %%
from sklearn.linear_model import Ridge
ridge = Ridge()
ridge.fit(X_train,y_train)
y_predict_ridge = ridge.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
rmse_feat_ridge = np.sqrt(mean_squared_error(y_test, y_predict_ridge))
round(rmse_feat_ridge,3)
# Out:
# 93.641

# %%
from sklearn.linear_model import Lasso
lasso = Lasso()
lasso.fit(X_train,y_train)
y_predict_lasso = lasso.predict(X_test)

# %%
def get_weights_df(model, feat, col_name):
  weights = pd.Series(model.coef_, feat.columns).sort_values()
  weights_df = pd.DataFrame(weights).reset_index()
  weights_df.columns = ['Features', col_name]
  weights_df[col_name].round(3)
  return weights_df

lasso_model_weights = get_weights_df(lasso, X_train, 'Lasso_Model_Weight')
lasso_model_weights
# Out:
#        Features  Lasso_Model_Weight
# 0            T9       -1.639155e+01
# 1            T2       -1.075746e+01
# 2          RH_2       -1.014653e+01
# 3          RH_8       -5.457679e+00
# 4         T_out       -3.696347e+00
# 5          RH_7       -1.724493e+00
# 6            T5       -1.589092e+00
# 7          RH_9       -1.549707e+00
# 8        RH_out       -1.821188e-02
# 9            T1       -0.000000e+00
# 10    Tdewpoint        0.000000e+00
# 11           T7       -0.000000e+00
# 12         RH_4        0.000000e+00
# 13           T4       -0.000000e+00
# 14          rv2        1.625869e-17
# 15          rv1        2.353054e-02
# 16  Press_mm_hg        8.695188e-02
# 17   Visibility        1.772175e-01
# 18         RH_5        2.509821e-01
# 19         RH_6        3.035808e-01
# 20    Windspeed        2.191789e+00
# 21         RH_3        3.657718e+00
# 22           T6        4.817203e+00
# 23           T8        6.597932e+00
# 24         RH_1        1.483957e+01
# ...

# %%
rmse_lasso = np.sqrt(mean_squared_error(y_test,y_predict_lasso))
round(rmse_lasso,3)
# Out:
# 93.892

# %% [markdown]
# # Normalized Version(normalization by MinMaxScaler is required in the quiz but the result is different from the answers)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('energydata_complete.csv')

# %%
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
df.isnull().sum(axis = 0)
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
X = df['T2']
y = df['T6']

X=df['T2'].values.reshape(-1,1)
y=df['T6'].values.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=77, test_size=0.3)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=77, test_size=0.3)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=77, test_size=0.3)

# %%
df = df.drop(columns=['date','lights'],axis=1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
normalized_df = pd.DataFrame(scaler.fit_transform(df),columns=df.columns)
normalized_df.head()
# Out:
#    Appliances       T1      RH_1        T2      RH_2        T3      RH_3  \
# 0    0.046729  0.32735  0.566187  0.225345  0.684038  0.215188  0.746066
# 1    0.046729  0.32735  0.541326  0.225345  0.682140  0.215188  0.748871
# 2    0.037383  0.32735  0.530502  0.225345  0.679445  0.215188  0.755569
# 3    0.037383  0.32735  0.524080  0.225345  0.678414  0.215188  0.758685
# 4    0.046729  0.32735  0.531419  0.225345  0.676727  0.215188  0.758685
#
#          T4      RH_4        T5  ...        T9      RH_9     T_out  \
# 0  0.351351  0.764262  0.175506  ...  0.223032  0.677290  0.372990
# 1  0.351351  0.782437  0.175506  ...  0.226500  0.678532  0.369239
# 2  0.344745  0.778062  0.175506  ...  0.219563  0.676049  0.365488
# 3  0.341441  0.770949  0.175506  ...  0.219563  0.671909  0.361736
# 4  0.341441  0.762697  0.178691  ...  0.219563  0.671909  0.357985
#
#    Press_mm_hg    RH_out  Windspeed  Visibility  Tdewpoint       rv1       rv2
# ...

# %%
feat_df = normalized_df.drop(columns=['Appliances'])
appliances = normalized_df['Appliances']

# %%
from sklearn.model_selection import train_test_split
lin_reg = LinearRegression()
X_train, X_test, y_train, y_test = train_test_split(feat_df, appliances, random_state=42, test_size=0.3)
lin_reg.fit(X_train,y_train)
y_predict= lin_reg.predict(X_test)

# %%
y_predict_train=lin_reg.predict(X_train)
from sklearn.metrics import mean_absolute_error
mae_train = mean_absolute_error(y_train, y_predict_train)
print('mae_train: ',round(mae_train,4))
# Out:
# mae_train:  0.0502

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_predict)
print('mae_test: ',round(mae,4))
# Out:
# mae_test:  0.0501

# %%
rmse_feat_train = np.sqrt(mean_squared_error(y_train, y_predict_train))
print('rmse_train: ',round(rmse_feat_train,3))
# Out:
# rmse_train:  0.089

# %%
from sklearn.metrics import mean_squared_error
rmse_feat = np.sqrt(mean_squared_error(y_test, y_predict))
print('rmse_test: ',round(rmse_feat,3))
# Out:
# rmse_test:  0.088

# %%
from sklearn.linear_model import Ridge
ridge = Ridge()
ridge.fit(X_train,y_train)
y_predict_ridge = ridge.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
rmse_feat_ridge = np.sqrt(mean_squared_error(y_test, y_predict_ridge))
round(rmse_feat_ridge,3)
# Out:
# 0.088

# %%
from sklearn.linear_model import Lasso
lasso = Lasso()
lasso.fit(X_train,y_train)
y_predict_lasso = lasso.predict(X_test)

# %%
def get_weights_df(model, feat, col_name):
  weights = pd.Series(model.coef_, feat.columns).sort_values()
  weights_df = pd.DataFrame(weights).reset_index()
  weights_df.columns = ['Features', col_name]
  weights_df[col_name].round(3)
  return weights_df

lasso_model_weights = get_weights_df(lasso, X_train, 'Lasso_Model_Weight')
lasso_model_weights
# Out:
#        Features  Lasso_Model_Weight
# 0            T1                 0.0
# 1     Tdewpoint                 0.0
# 2    Visibility                 0.0
# 3     Windspeed                 0.0
# 4        RH_out                -0.0
# 5   Press_mm_hg                -0.0
# 6         T_out                 0.0
# 7          RH_9                -0.0
# 8            T9                 0.0
# 9          RH_8                -0.0
# 10           T8                 0.0
# 11         RH_7                -0.0
# 12           T7                 0.0
# 13         RH_6                -0.0
# 14           T6                 0.0
# 15         RH_5                 0.0
# 16           T5                 0.0
# 17         RH_4                 0.0
# 18           T4                 0.0
# 19         RH_3                 0.0
# 20           T3                 0.0
# 21         RH_2                -0.0
# 22           T2                 0.0
# 23         RH_1                 0.0
# 24          rv1                -0.0
# ...

# %%
rmse_lasso = np.sqrt(mean_squared_error(y_test,y_predict_lasso))
round(rmse_lasso,3)
# Out:
# 0.095
